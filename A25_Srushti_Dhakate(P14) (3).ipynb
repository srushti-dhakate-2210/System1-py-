# %% [markdown]
# * Name: Srushti Dhakate
# * Roll No: 25
# * Section: A
# * Batch: A2
# * Branch: CSE (First Shift)
# * Subject: Systems Lab - 1
# * **Practical 14**

# %% [markdown]
# AUTOMOBILE

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/gdrive/MyDrive/Automobile.csv")

# %%
df
# Out:
#         company   body-style  wheel-base  ...  horsepower average-mileage    price
# 0   alfa-romero  convertible        88.6  ...         111              21  13495.0
# 1   alfa-romero  convertible        88.6  ...         111              21  16500.0
# 2   alfa-romero    hatchback        94.5  ...         154              19  16500.0
# 3          audi        sedan        99.8  ...         102              24  13950.0
# 4          audi        sedan        99.4  ...         115              18  17450.0
# ..          ...          ...         ...  ...         ...             ...      ...
# 56   volkswagen        sedan        97.3  ...          85              27   7975.0
# 57   volkswagen        sedan        97.3  ...          52              37   7995.0
# 58   volkswagen        sedan        97.3  ...         100              26   9995.0
# 59        volvo        sedan       104.3  ...         114              23  12940.0
# ...

# %%
#to get the number of rows and columns in the given dataframe
shape =df.shape
print(shape)
print("The number of rows in data frame = ",shape[0])
print("The number of columns in data frame = ",shape[1])
# Out:
# (61, 9)
# The number of rows in data frame =  61
# The number of columns in data frame =  9

# %%
#to get the number of rows
print("The number of rows in dataframe :",shape[0])
# Out:
# The number of rows in dataframe : 61

# %%
#to get the number of columns
print("The number of columns in dataframe :",shape[1])
# Out:
# The number of columns in dataframe : 9

# %%
#to get information about dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.4+ KB
# None

# %%
#to print first five rows
print(df.head(5))
# Out:
#        company   body-style  wheel-base  ...  horsepower average-mileage    price
# 0  alfa-romero  convertible        88.6  ...         111              21  13495.0
# 1  alfa-romero  convertible        88.6  ...         111              21  16500.0
# 2  alfa-romero    hatchback        94.5  ...         154              19  16500.0
# 3         audi        sedan        99.8  ...         102              24  13950.0
# 4         audi        sedan        99.4  ...         115              18  17450.0
#
# [5 rows x 9 columns]

# %%
#to print last five rows
print(df.tail(5))
# Out:
#        company body-style  wheel-base  ...  horsepower average-mileage    price
# 56  volkswagen      sedan        97.3  ...          85              27   7975.0
# 57  volkswagen      sedan        97.3  ...          52              37   7995.0
# 58  volkswagen      sedan        97.3  ...         100              26   9995.0
# 59       volvo      sedan       104.3  ...         114              23  12940.0
# 60       volvo      wagon       104.3  ...         114              23  13415.0
#
# [5 rows x 9 columns]

# %%
#To get information about dataframe
print(df.describe())
# Out:
#        wheel-base      length  horsepower  average-mileage         price
# count   61.000000   61.000000   61.000000        61.000000     58.000000
# mean    98.481967  173.098361  107.852459        25.803279  15387.000000
# std      6.679234   14.021846   53.524398         8.129821  11320.259841
# min     88.400000  141.100000   48.000000        13.000000   5151.000000
# 25%     94.500000  159.100000   68.000000        19.000000   6808.500000
# 50%     96.300000  171.200000  100.000000        25.000000  11095.000000
# 75%    101.200000  177.300000  123.000000        31.000000  18120.500000
# max    120.900000  208.100000  288.000000        47.000000  45400.000000

# %%
print(df.head((7)))
# Out:
#        company   body-style  wheel-base  ...  horsepower average-mileage    price
# 0  alfa-romero  convertible        88.6  ...         111              21  13495.0
# 1  alfa-romero  convertible        88.6  ...         111              21  16500.0
# 2  alfa-romero    hatchback        94.5  ...         154              19  16500.0
# 3         audi        sedan        99.8  ...         102              24  13950.0
# 4         audi        sedan        99.4  ...         115              18  17450.0
# 5         audi        sedan        99.8  ...         110              19  15250.0
# 6         audi        wagon       105.8  ...         110              19  18920.0
#
# [7 rows x 9 columns]

# %%
#To print all volvo cars available
print(df.loc[df['company']=='volvo'])
# Out:
#    company body-style  wheel-base  ...  horsepower average-mileage    price
# 59   volvo      sedan       104.3  ...         114              23  12940.0
# 60   volvo      wagon       104.3  ...         114              23  13415.0
#
# [2 rows x 9 columns]

# %%
#To print all toyota cars available
print(df.loc[df['company']=='toyota'])
# Out:
#    company body-style  wheel-base  ...  horsepower average-mileage    price
# 48  toyota  hatchback        95.7  ...          62              35   5348.0
# 49  toyota  hatchback        95.7  ...          62              31   6338.0
# 50  toyota  hatchback        95.7  ...          62              31   6488.0
# 51  toyota      wagon        95.7  ...          62              31   6918.0
# 52  toyota      wagon        95.7  ...          62              27   7898.0
# 53  toyota      wagon        95.7  ...          62              27   8778.0
# 54  toyota      wagon       104.5  ...         156              19  15750.0
#
# [7 rows x 9 columns]

# %%
#To print all audi cars available
print(df.loc[df['company']=='audi'])
# Out:
#   company body-style  wheel-base  ...  horsepower average-mileage    price
# 3    audi      sedan        99.8  ...         102              24  13950.0
# 4    audi      sedan        99.4  ...         115              18  17450.0
# 5    audi      sedan        99.8  ...         110              19  15250.0
# 6    audi      wagon       105.8  ...         110              19  18920.0
#
# [4 rows x 9 columns]

# %%
print(df.loc[df['company']=='mercedes'])
# Out:
# Empty DataFrame
# Columns: [company, body-style, wheel-base, length, engine-type, num-of-cylinders, horsepower, average-mileage, price]
# Index: []

# %%
df1 = pd.DataFrame([[2,3],[5,6],[8,9]],
index = ['cobra','viper','sidewinder'],
columns = ['max_speed','shield'])

df1
# Out:
#             max_speed  shield
# cobra               2       3
# viper               5       6
# sidewinder          8       9

# %%
df1.loc['viper']
# Out:
# max_speed    5
# shield       6
# Name: viper, dtype: int64

# %%
df1.shape
# Out:
# (3, 2)

# %%
df1.loc['cobra':'viper','max_speed']
# Out:
# cobra    2
# viper    5
# Name: max_speed, dtype: int64

# %%
#tells which index you want to set as false or true
df1.loc[[False,False,True]]
# Out:
#             max_speed  shield
# sidewinder          8       9

# %%
df1.loc[lambda df1 : df1 ['shield'] == 9]
# Out:
#             max_speed  shield
# sidewinder          8       9

# %%
df1.loc[df1['shield']>6,['max_speed']]
# Out:
#             max_speed
# sidewinder          8

# %%
df1.loc[df1['shield']>6]
# Out:
#             max_speed  shield
# sidewinder          8       9

# %%
#Count total cars per company
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
#Find the most expensive car company name and its price 
dfmostexpensive = df [['company','price']][df.price==df['price'].max() ]
dfmostexpensive
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
#Find the most cheap car company name and its price 
dfmostcheap = df [['company','price']][df.price==df['price'].min() ]
dfmostcheap
# Out:
#       company   price
# 13  chevrolet  5151.0

# %%
#Find each company's highest price car
car_Manufacturers =df.groupby('company')
priceDf = car_Manufacturers['company','price'].max()
priceDf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
#Find each company's highest price car
car_Manufacturers =df.groupby('company')
priceDf = car_Manufacturers['company','price'].min()
priceDf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      company    price
# company
# alfa-romero      alfa-romero  13495.0
# audi                    audi  13950.0
# bmw                      bmw  16430.0
# chevrolet          chevrolet   5151.0
# dodge                  dodge   6229.0
# honda                  honda   7295.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  32250.0
# mazda                  mazda   5195.0
# mercedes-benz  mercedes-benz  25552.0
# mitsubishi        mitsubishi   5389.0
# nissan                nissan   6649.0
# porsche              porsche  34028.0
# toyota                toyota   5348.0
# volkswagen        volkswagen   7775.0
# volvo                  volvo  12940.0

# %%
#find the average mileage of each car making company
car_Manufacturers = df.groupby('company')
avgmileageDf =car_Manufacturers['company','average-mileage'].mean()
avgmileageDf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %%
#Sort all cars by price column
import pandas as pd
carsDf = pd.read_csv("/content/gdrive/MyDrive/Automobile.csv")
carsDf = carsDf.sort_values(by=['price'], ascending=False)
carsDf.head(10)
# Out:
#           company   body-style  ...  average-mileage    price
# 35  mercedes-benz      hardtop  ...               14  45400.0
# 11            bmw        sedan  ...               16  41315.0
# 34  mercedes-benz        sedan  ...               14  40960.0
# 46        porsche  convertible  ...               17  37028.0
# 12            bmw        sedan  ...               15  36880.0
# 26         jaguar        sedan  ...               13  36000.0
# 25         jaguar        sedan  ...               15  35550.0
# 45        porsche      hardtop  ...               17  34028.0
# 24         jaguar        sedan  ...               15  32250.0
# 10            bmw        sedan  ...               16  30760.0
#
# [10 rows x 9 columns]

# %%
#Sort all cars by price column
import pandas as pd
carsDf = pd.read_csv("/content/gdrive/MyDrive/Automobile.csv")
carsDf = carsDf.sort_values(by=['price'], ascending=True)
carsDf.head(10)
# Out:
#        company body-style  wheel-base  ...  horsepower average-mileage   price
# 13   chevrolet  hatchback        88.4  ...          48              47  5151.0
# 27       mazda  hatchback        93.1  ...          68              30  5195.0
# 48      toyota  hatchback        95.7  ...          62              35  5348.0
# 36  mitsubishi  hatchback        93.7  ...          68              37  5389.0
# 28       mazda  hatchback        93.1  ...          68              31  6095.0
# 37  mitsubishi  hatchback        93.7  ...          68              31  6189.0
# 17       dodge  hatchback        93.7  ...          68              31  6229.0
# 14   chevrolet  hatchback        94.5  ...          70              38  6295.0
# 49      toyota  hatchback        95.7  ...          62              31  6338.0
# 16       dodge  hatchback        93.7  ...          68              31  6377.0
#
# [10 rows x 9 columns]

# %%
#sorting by price in ascending order

carsdf=df.sort_values(by=["price"], ascending=True)
carsdf.head(10)
# Out:
#        company body-style  wheel-base  ...  horsepower average-mileage   price
# 13   chevrolet  hatchback        88.4  ...          48              47  5151.0
# 27       mazda  hatchback        93.1  ...          68              30  5195.0
# 48      toyota  hatchback        95.7  ...          62              35  5348.0
# 36  mitsubishi  hatchback        93.7  ...          68              37  5389.0
# 28       mazda  hatchback        93.1  ...          68              31  6095.0
# 37  mitsubishi  hatchback        93.7  ...          68              31  6189.0
# 17       dodge  hatchback        93.7  ...          68              31  6229.0
# 14   chevrolet  hatchback        94.5  ...          70              38  6295.0
# 49      toyota  hatchback        95.7  ...          62              31  6338.0
# 16       dodge  hatchback        93.7  ...          68              31  6377.0
#
# [10 rows x 9 columns]

# %%
#default order of sort_value is ascending

carsdf=df.sort_values(by=["price"])
carsdf.head(10)
# Out:
#        company body-style  wheel-base  ...  horsepower average-mileage   price
# 13   chevrolet  hatchback        88.4  ...          48              47  5151.0
# 27       mazda  hatchback        93.1  ...          68              30  5195.0
# 48      toyota  hatchback        95.7  ...          62              35  5348.0
# 36  mitsubishi  hatchback        93.7  ...          68              37  5389.0
# 28       mazda  hatchback        93.1  ...          68              31  6095.0
# 37  mitsubishi  hatchback        93.7  ...          68              31  6189.0
# 17       dodge  hatchback        93.7  ...          68              31  6229.0
# 14   chevrolet  hatchback        94.5  ...          70              38  6295.0
# 49      toyota  hatchback        95.7  ...          62              31  6338.0
# 16       dodge  hatchback        93.7  ...          68              31  6377.0
#
# [10 rows x 9 columns]

# %%
#Making two dictionaries
GermanCars = {'company':['Ford','Mercedes','BMV','Audi'],'Price':[23845,171995,135925,71400]}
japaneseCars = { 'company': ['Toyota','Honda','Nissan','Mitsubishi'],'Price':[29995,23600,61500,58900]}

print("First Dictionaries ")
print(GermanCars)
print("Second Dictionaries ")
print(japaneseCars)
# Out:
# First Dictionaries
# {'company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925, 71400]}
# Second Dictionaries
# {'company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi'], 'Price': [29995, 23600, 61500, 58900]}

# %%
#concatenate two data frames using the following conditions 
import pandas as pd
German_cars={"company":["ford", "mercedes", "BMV", "audi"], "price":[23845, 171995, 135925, 71400]}
carsdf1=pd.DataFrame.from_dict(German_cars)
japanese_cars={"company": ["toyota", "honda", "nissa", "mitsubihsi"], "price":[29995, 23600, 61500, 58900]}
carsdf2=pd.DataFrame.from_dict(japanese_cars)
carsdf=pd.concat([carsdf1, carsdf2], keys=["Germany", "Japan"])
carsdf
# Out:
#               company   price
# Germany 0        ford   23845
#         1    mercedes  171995
#         2         BMV  135925
#         3        audi   71400
# Japan   0      toyota   29995
#         1       honda   23600
#         2       nissa   61500
#         3  mitsubihsi   58900

# %%
df.loc[0:60, 'price']
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
df.iloc[:,-1:]
# Out:
#       price
# 0   13495.0
# 1   16500.0
# 2   16500.0
# 3   13950.0
# 4   17450.0
# ..      ...
# 56   7975.0
# 57   7995.0
# 58   9995.0
# 59  12940.0
# 60  13415.0
#
# [61 rows x 1 columns]

# %%
df.corr()
# Out:
#                  wheel-base    length  horsepower  average-mileage     price
# wheel-base         1.000000  0.878381    0.463421        -0.547325  0.663085
# length             0.878381  1.000000    0.668555        -0.788429  0.788465
# horsepower         0.463421  0.668555    1.000000        -0.808804  0.901707
# average-mileage   -0.547325 -0.788429   -0.808804         1.000000 -0.770217
# price              0.663085  0.788465    0.901707        -0.770217  1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/gdrive/MyDrive/Automobile.csv")

# %%
#scatter plot of average-mileage vs price
plt.scatter(df['average-mileage'],df['price'],c='red')
plt.xlabel('average-mileage')
plt.ylabel('price')
plt.show()

# %%
#scatter plot of average-mileage vs price having default color as blue
plt.scatter(df['average-mileage'],df['price'])
plt.xlabel('average-mileage')
plt.ylabel('price')
plt.show()

# %%
#scatter plot of average-mileage vs price
plt.scatter(df['horsepower'],df['price'],c='red')
plt.xlabel('average-mileage')
plt.ylabel('price')
plt.show()

# %%
#plot histogram of price
color=("red ","green","blue")
plt.hist(df['price'],color='green',edgecolor='white',bins=10)
plt.show()

# %%
#simple plot
plt.plot(df['average-mileage'], df['price'])
plt.xlabel('average-mileage')
plt.ylabel('price')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(df['average-mileage'])
plt.show()

# %%
import seaborn as sns
sns.boxplot(y=df["average-mileage"])

# %%
sns.boxplot(y=df["price"])
